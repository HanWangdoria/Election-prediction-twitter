# %%
import pandas as pd
import numpy as np
import tweepy
import requests
import re
import time
from tweepy import OAuthHandler
from twython import Twython, TwythonError

# %%
APP_KEY =  'cpUjD93yJqxAJhM4ubE6vJO4q'
APP_SECRET = 'amdRJXn0G6mi4zaLonep2Vjq9sezr4CIHNROVNIsUQyJWtjQbk'

twitter = Twython(APP_KEY, APP_SECRET)
#5

# %%
def get_re_info (response): 
    len_r = len(response)
    j=0
    while j < len_r:
         # retweets_id
        re_id = response[j].get("id")
        
         # original tweets owner
        #tweet_owner_screen_name = response[j].get("entities").get("user_mentions")[0].get("screen_name")
        
         # retweeted_people_id
        re_people_id = response[j].get("user").get("id")
                    
         # retweeted_people_screen_name
        re_people_name = response[j].get("user").get("screen_name")
            
        # retweeted_people_followers
        re_people_fo_num = response[j].get("user").get("followers_count")
            
        #retweeted_people_friends
        re_people_friends_num = response[j].get("user").get("friends_count")
            
        #retweeted_content
        re_text = response[j].get("text").encode('unicode_escape') #unicode escape to fix emoji issue
                    
            
        df1= pd.DataFrame({ "re_people_id": [re_people_id],
                            "re_people_name": [re_people_name],
                            "re_people_fo_num" : [re_people_fo_num],
                            "re_people_friends_num" : [re_people_friends_num],
                            "re_id" : [re_id],
                            "re_text" : [re_text],
                        })
        
        print(len(df1))
        
        j=j+1
        return df1

# %%
from twython.exceptions import TwythonRateLimitError, TwythonError
from twython import Twython, TwythonStreamer

# %%
if __name__ == '__main__':
    with open('set_crawler4.txt', 'r') as f:
        content = f.readlines()
    # you may also want to remove whitespace characters like `\n` at the end of each line
        content = [x.strip() for x in content] 
    
    for strs in content:
        tweets_o = pd.read_csv("%s_cleaned_tweets.csv" %strs)
        length = len(tweets_o['id'])
    
        feature_columns = ["re_people_id","re_people_name","re_people_fo_num",
                           "re_people_friends_num","re_id","re_text"]
    
        df_final = pd.DataFrame(columns=feature_columns)
    
        id_list =[]
    
        i = 0 
        while i < 100:
                id_list = tweets_o['id']
            #limited_id_list = id_list[0: 50]
     
                response = twitter.get_retweets(id=id_list[i], count=100)
                time.sleep(2)
                len_r = len(response)
            
                if len_r == 0:
                    print("this tweets didn't been retweeted.")
                    i=i+1
                    continue

                else:
                    df1= get_re_info(response)
                    result = df_final.append(df1)
                    result.to_csv('%s_retweeted_details.csv' %strs,mode='a',header=False) 
                    print("this retweets have been appended.")
                    i=i+1
                    print(i)
        
        print("%s has done!" %strs)
        time.sleep(150)
# Out:
# 1
# this retweets have been appended.
# 1
# 1
# this retweets have been appended.
# 2
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 4
# 1
# this retweets have been appended.
# 5
# 1
# this retweets have been appended.
# 6
# 1
# this retweets have been appended.
# 7
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 12
# 1
# this retweets have been appended.
# 13
# 1
# this retweets have been appended.
# 14
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 16
# 1
# this retweets have been appended.
# 17
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 19
# 1
# this retweets have been appended.
# 20
# 1
# this retweets have been appended.
# 21
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 23
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 25
# 1
# this retweets have been appended.
# 26
# 1
# this retweets have been appended.
# 27
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 31
# 1
# this retweets have been appended.
# 32
# 1
# this retweets have been appended.
# 33
# 1
# this retweets have been appended.
# 34
# 1
# this retweets have been appended.
# 35
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 37
# 1
# this retweets have been appended.
# 38
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 40
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 42
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 44
# 1
# this retweets have been appended.
# 45
# 1
# this retweets have been appended.
# 46
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 49
# 1
# this retweets have been appended.
# 50
# 1
# this retweets have been appended.
# 51
# 1
# this retweets have been appended.
# 52
# 1
# this retweets have been appended.
# 53
# 1
# this retweets have been appended.
# 54
# 1
# this retweets have been appended.
# 55
# 1
# this retweets have been appended.
# 56
# 1
# this retweets have been appended.
# 57
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 59
# 1
# this retweets have been appended.
# 60
# 1
# this retweets have been appended.
# 61
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 63
# 1
# this retweets have been appended.
# 64
# 1
# this retweets have been appended.
# 65
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 67
# 1
# this retweets have been appended.
# 68
# 1
# this retweets have been appended.
# 69
# 1
# this retweets have been appended.
# 70
# 1
# this retweets have been appended.
# 71
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 73
# 1
# this retweets have been appended.
# 74
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 76
# 1
# this retweets have been appended.
# 77
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 79
# 1
# this retweets have been appended.
# 80
# 1
# this retweets have been appended.
# 81
# 1
# this retweets have been appended.
# 82
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 85
# 1
# this retweets have been appended.
# 86
# 1
# this retweets have been appended.
# 87
# 1
# this retweets have been appended.
# 88
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 90
# 1
# this retweets have been appended.
# 91
# 1
# this retweets have been appended.
# 92
# 1
# this retweets have been appended.
# 93
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 95
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 98
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 100
# sarahwollaston has done!
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# RobNolanTruro has done!
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 20
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 43
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 49
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 52
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 63
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 65
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 79
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 91
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 94
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 96
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# aapennington has done!
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 6
# 1
# this retweets have been appended.
# 7
# 1
# this retweets have been appended.
# 8
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 10
# 1
# this retweets have been appended.
# 11
# 1
# this retweets have been appended.
# 12
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 15
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 20
# 1
# this retweets have been appended.
# 21
# 1
# this retweets have been appended.
# 22
# 1
# this retweets have been appended.
# 23
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 29
# 1
# this retweets have been appended.
# 30
# 1
# this retweets have been appended.
# 31
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 33
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 37
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 42
# 1
# this retweets have been appended.
# 43
# 1
# this retweets have been appended.
# 44
# 1
# this retweets have been appended.
# 45
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 47
# 1
# this retweets have been appended.
# 48
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 50
# 1
# this retweets have been appended.
# 51
# 1
# this retweets have been appended.
# 52
# 1
# this retweets have been appended.
# 53
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 57
# 1
# this retweets have been appended.
# 58
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 80
# 1
# this retweets have been appended.
# 81
# 1
# this retweets have been appended.
# 82
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 84
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 92
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# alancampbellmp has done!
# 1
# this retweets have been appended.
# 1
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 13
# 1
# this retweets have been appended.
# 14
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 17
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 42
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 44
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 53
# 1
# this retweets have been appended.
# 54
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 78
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 84
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 88
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# Alliance_UpBann has done!
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 12
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 38
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 58
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 85
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 99
# this tweets didn't been retweeted.
# JohnODowdSF has done!
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 2
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 8
# 1
# this retweets have been appended.
# 9
# 1
# this retweets have been appended.
# 10
# 1
# this retweets have been appended.
# 11
# 1
# this retweets have been appended.
# 12
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 18
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 20
# 1
# this retweets have been appended.
# 21
# 1
# this retweets have been appended.
# 22
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 24
# 1
# this retweets have been appended.
# 25
# 1
# this retweets have been appended.
# 26
# 1
# this retweets have been appended.
# 27
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 29
# 1
# this retweets have been appended.
# 30
# 1
# this retweets have been appended.
# 31
# 1
# this retweets have been appended.
# 32
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 34
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 38
# 1
# this retweets have been appended.
# 39
# 1
# this retweets have been appended.
# 40
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 43
# 1
# this retweets have been appended.
# 44
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 51
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 54
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 56
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 58
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 62
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 65
# 1
# this retweets have been appended.
# 66
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 71
# 1
# this retweets have been appended.
# 72
# 1
# this retweets have been appended.
# 73
# 1
# this retweets have been appended.
# 74
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 76
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 78
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 93
# 1
# this retweets have been appended.
# 94
# 1
# this retweets have been appended.
# 95
# 1
# this retweets have been appended.
# 96
# 1
# this retweets have been appended.
# 97
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# CamillaBeaven has done!
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 6
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 13
# 1
# this retweets have been appended.
# 14
# 1
# this retweets have been appended.
# 15
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 17
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 27
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 48
# 1
# this retweets have been appended.
# 49
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 51
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 53
# 1
# this retweets have been appended.
# 54
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 57
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 64
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 71
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 73
# 1
# this retweets have been appended.
# 74
# 1
# this retweets have been appended.
# 75
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 77
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 82
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 87
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 95
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 100
# lovell0711 has done!
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 10
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 13
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 15
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 20
# 1
# this retweets have been appended.
# 21
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 24
# 1
# this retweets have been appended.
# 25
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 27
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 34
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 36
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 40
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 42
# 1
# this retweets have been appended.
# 43
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 45
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 49
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 53
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 55
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 58
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 62
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 67
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 70
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 72
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 75
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 78
# 1
# this retweets have been appended.
# 79
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 81
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 83
# 1
# this retweets have been appended.
# 84
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# dollytheis has done!
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# CaplinDebbie has done!
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 6
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 9
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 17
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 22
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 29
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 31
# 1
# this retweets have been appended.
# 32
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 36
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 39
# 1
# this retweets have been appended.
# 40
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 43
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 49
# 1
# this retweets have been appended.
# 50
# 1
# this retweets have been appended.
# 51
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 53
# 1
# this retweets have been appended.
# 54
# 1
# this retweets have been appended.
# 55
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 58
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 67
# 1
# this retweets have been appended.
# 68
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 71
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 73
# 1
# this retweets have been appended.
# 74
# 1
# this retweets have been appended.
# 75
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 77
# 1
# this retweets have been appended.
# 78
# 1
# this retweets have been appended.
# 79
# 1
# this retweets have been appended.
# 80
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 84
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 86
# 1
# this retweets have been appended.
# 87
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# 1
# this retweets have been appended.
# 91
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# angelaeagle has done!
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# this tweets didn't been retweeted.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-110-692fed10ceb9> in <module>()
#      21             #limited_id_list = id_list[0: 50]
#      22
# ---> 23                 response = twitter.get_retweets(id=id_list[i], count=100)
#      24                 time.sleep(2)
#      25                 len_r = len(response)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in __getitem__(self, key)
#     599         key = com._apply_if_callable(key, self)
#     600         try:
# --> 601             result = self.index.get_value(self, key)
#     602
#     603             if not is_scalar(result):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    2475         try:
#    2476             return self._engine.get_value(s, k,
# -> 2477                                           tz=getattr(series.dtype, 'tz', None))
#    2478         except KeyError as e1:
#    2479             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 45

# %%
APP_KEY =  'cpUjD93yJqxAJhM4ubE6vJO4q'
APP_SECRET = 'amdRJXn0G6mi4zaLonep2Vjq9sezr4CIHNROVNIsUQyJWtjQbk'

twitter = Twython(APP_KEY, APP_SECRET)
#5

# %%
APP_KEY =  'Tf7rC6i7eSIfZFpuS8OoqmkDb'
APP_SECRET = 'vp6lIJf5Wuq6j7MNPaQSyq5Jlu7oXRPL7d9pz0TkEGIiDSEjRL'

twitter = Twython(APP_KEY, APP_SECRET)
#9
