# %%
import pandas as pd
import numpy as np
import tweepy
import requests
import re
import time
import matplotlib.pyplot as plt

# %%
import networkx as nx
from __future__ import print_function, division
import time

# %%
t0 = time.time()
df_o = pd.read_csv('Gephi_data_cleaned.csv')

print("%.2f secs ==> pd.read_csv"%(time.time()-t0))
# Out:
# 0.11 secs ==> pd.read_csv

# %%
df_o.head(5)
# Out:
#             Id  Label  timeset  indegree  outdegree  Degree  \
# 0        Termy    NaN      NaN         2          6       8
# 1  EconomyAsks    NaN      NaN        21          0      21
# 2  ThreeWomen_    NaN      NaN         1          0       1
# 3  jonsessions    NaN      NaN         2          0       2
# 4  andypatmore    NaN      NaN         3          0       3
#
#    weighted indegree  weighted outdegree  Weighted Degree  Eccentricity  \
# 0                828               12051            12879             1
# 1             156071                   0           156071             0
# 2               2031                   0             2031             0
# 3               1115                   0             1115             0
# 4                777                   0              777             0
#
#         ...        betweenesscentrality  modularity_class  pageranks  \
# 0       ...                        21.5                 5   0.000054
# ...

# %%
df1= df_o.drop("Label",1)
df1.head(5)
# Out:
#             Id  timeset  indegree  outdegree  Degree  weighted indegree  \
# 0        Termy      NaN         2          6       8                828
# 1  EconomyAsks      NaN        21          0      21             156071
# 2  ThreeWomen_      NaN         1          0       1               2031
# 3  jonsessions      NaN         2          0       2               1115
# 4  andypatmore      NaN         3          0       3                777
#
#    weighted outdegree  Weighted Degree  Eccentricity  closnesscentrality  \
# 0               12051            12879             1                 1.0
# 1                   0           156071             0                 0.0
# 2                   0             2031             0                 0.0
# 3                   0             1115             0                 0.0
# 4                   0              777             0                 0.0
#
#         ...        betweenesscentrality  modularity_class  pageranks  \
# ...

# %%
df2=df1.drop("timeset",1)
df2.head(5)
# Out:
#             Id  indegree  outdegree  Degree  weighted indegree  \
# 0        Termy         2          6       8                828
# 1  EconomyAsks        21          0      21             156071
# 2  ThreeWomen_         1          0       1               2031
# 3  jonsessions         2          0       2               1115
# 4  andypatmore         3          0       3                777
#
#    weighted outdegree  Weighted Degree  Eccentricity  closnesscentrality  \
# 0               12051            12879             1                 1.0
# 1                   0           156071             0                 0.0
# 2                   0             2031             0                 0.0
# 3                   0             1115             0                 0.0
# 4                   0              777             0                 0.0
#
#    harmonicclosnesscentrality  betweenesscentrality  modularity_class  \
# 0                         1.0                  21.5                 5
# ...

# %%
t0 = time.time()
df_out = pd.read_csv('out.csv')

print("%.2f secs ==> pd.read_csv"%(time.time()-t0))
# Out:
# 0.01 secs ==> pd.read_csv

# %%
name_list = df_out['screen_name'].tolist()
print(len(name_list))
# Out:
# 1685

# %%
df_cleaned= df2[df2['screen_name'].isin(name_list)]
df_cleaned.head(5)
# Out:
#             Id  indegree  outdegree  Degree  weighted indegree  \
# 0        Termy         2          6       8                828
# 1  EconomyAsks        21          0      21             156071
# 2  ThreeWomen_         1          0       1               2031
# 3  jonsessions         2          0       2               1115
# 4  andypatmore         3          0       3                777
#
#    weighted outdegree  Weighted Degree  Eccentricity  closnesscentrality  \
# 0               12051            12879             1                 1.0
# 1                   0           156071             0                 0.0
# 2                   0             2031             0                 0.0
# 3                   0             1115             0                 0.0
# 4                   0              777             0                 0.0
#
#    harmonicclosnesscentrality  betweenesscentrality  modularity_class  \
# 0                         1.0                  21.5                 5
# ...

# %%
print(len(df_cleaned))
# Out:
# 1685

# %%
df_cleaned.to_csv("cleaned_gephi.csv")
