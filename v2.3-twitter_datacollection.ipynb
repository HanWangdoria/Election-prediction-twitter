# %%
import pandas as pd 
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
from os import path
import json
import csv

import tweepy #https://github.com/tweepy/tweepy

# %%
#2.0 version
#Twitter API credentials
consumer_key = "dVSgiSlSsh9ZJXOkaOV4n57k6"
consumer_secret = "HL537ukFl6oWplss9VxSZmwwIbDBWbzcpF14IPy9UtR6tHessm"
access_key = "921917165950906368-PO3ER1zbxWuyC6hyTfxm4Y3486q3HqZ"
access_secret = "KcfkGpLZ9L3lyOhka9peKHCXvIvtyY4pdx6kTm0ALhkVX"

# %%
def get_all_tweets(screen_name):
    #Twitter only allows access to a users most recent 3240 tweets with this method

    #authorize twitter, initialize tweepy
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_key, access_secret)
    api = tweepy.API(auth)

    #initialize a list to hold all the tweepy Tweets
    alltweets = []  

    #make initial request for most recent tweets (200 is the maximum allowed count)
    new_tweets = api.user_timeline(screen_name = screen_name,count=200)

    #save most recent tweets
    alltweets.extend(new_tweets)

    #save the id of the oldest tweet less one
    oldest = alltweets[-1].id - 1

    #keep grabbing tweets until there are no tweets left to grab
    while len(new_tweets) > 0:
        print ("getting tweets before %s" % (oldest))

        #all subsiquent requests use the max_id param to prevent duplicates
        new_tweets = api.user_timeline(screen_name = screen_name,count=200,max_id=oldest)

        #save most recent tweets
        alltweets.extend(new_tweets)

        #update the id of the oldest tweet less one
        oldest = alltweets[-1].id - 1

        print ("...%s tweets downloaded so far" % (len(alltweets)))

    #transform the tweepy tweets into a 2D array that will populate the csv 
    outtweets = [[tweet.id_str, 
                  tweet.created_at, 
                  tweet.text.encode("utf-8"),
                  len(tweet.text),
                  tweet.source,
                  tweet.favorite_count,
                  tweet.retweet_count,
                 ] for tweet in alltweets]

    #write the csv  
    with open('%s_tweets.csv' % screen_name, 'w') as f:
        writer = csv.writer(f)
        writer.writerow(["id","created_at","text","len","source","fav_count","rt_count"])
        writer.writerows(outtweets)

# %%
#Using a txt file to store the MP's names 
#read txt file into string lists and looping for next steps
with open('set_crawler3.txt', 'r') as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content] 
print(content[0])
# Out:
# johnpotterLD

# %%
print(len(content))
# Out:
# 19

# %%
if __name__ == '__main__':
    #pass in the username of the account want to download
    #my account as a test sample
    for strs in content:
        get_all_tweets(strs)
# Out:
# getting tweets before 997823650517716991
# ...399 tweets downloaded so far
# getting tweets before 970011187269308415
# ...599 tweets downloaded so far
# getting tweets before 936726020228558847
# ...799 tweets downloaded so far
# getting tweets before 898254221438484480
# ...998 tweets downloaded so far
# getting tweets before 868033844661944319
# ...1198 tweets downloaded so far
# getting tweets before 842686285269667839
# ...1397 tweets downloaded so far
# getting tweets before 812552891835830271
# ...1596 tweets downloaded so far
# getting tweets before 776650729314480127
# ...1796 tweets downloaded so far
# getting tweets before 745304829052981251
# ...1994 tweets downloaded so far
# getting tweets before 704952469743398911
# ...2194 tweets downloaded so far
# getting tweets before 667296898353512447
# ...2394 tweets downloaded so far
# getting tweets before 642658561550512127
# ...2594 tweets downloaded so far
# getting tweets before 597002262192467968
# ...
